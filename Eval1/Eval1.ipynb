# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import pylab as plt
from matplotlib import rc
from pylab import figure, show, legend, xlabel, ylabel

# %%
df = pd.read_csv("/home/rodolfoch/Computacional/Eval1/GLB.Ts+dSST.csv",skiprows=1)

# %%
df.columns= ['Year','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','JD','DN','DJF','MAM','JJA','SON']

# %%
df.head(138)
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.29  -.21  -.18  -.27  -.14  -.29  -.23  -.08  -.16  -.15  -.18
# 1    1881 -0.10  -.14   .01  -.03  -.04  -.28  -.06  -.02  -.09  -.20  -.26
# 2    1882  0.09   .08   .01  -.20  -.17  -.25  -.11   .03   .00  -.23  -.21
# 3    1883 -0.34  -.42  -.18  -.24  -.26  -.13  -.09  -.14  -.19  -.12  -.21
# 4    1884 -0.18  -.12  -.35  -.36  -.32  -.38  -.34  -.26  -.23  -.22  -.30
# 5    1885 -0.65  -.29  -.23  -.45  -.42  -.50  -.28  -.27  -.18  -.19  -.22
# 6    1886 -0.42  -.46  -.41  -.29  -.27  -.39  -.16  -.31  -.19  -.24  -.25
# 7    1887 -0.66  -.48  -.31  -.37  -.33  -.20  -.18  -.27  -.19  -.32  -.25
# 8    1888 -0.43  -.42  -.47  -.28  -.22  -.20  -.09  -.11  -.06   .01   .01
# 9    1889 -0.21   .14   .04   .04  -.03  -.11  -.05  -.17  -.18  -.22  -.32
# 10   1890 -0.48  -.48  -.41  -.37  -.48  -.27  -.30  -.36  -.35  -.22  -.37
# ...

# %%
df.Year= pd.to_numeric(df.Year, errors='coerce')
df.JD= pd.to_numeric(df.JD, errors='coerce')

# %%
x=df[u'Year']
y=df[u'JD']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Año')
plt.ylabel('Temperatura(C°)')
plt.title('Temperatura promedio anual')
plt.plot(x,y, color='black')

# %%
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
lowess = sm.nonparametric.lowess
x = np.random.uniform(low = -2*np.pi, high = 2*np.pi, size=500)
y = np.sin(x) + np.random.normal(size=len(x))
z = lowess(y, x)
w = lowess(y, x, frac=1./3)

plt.plot(x,y)


plt.show()

# %%
import statsmodels.api as sm

# %%
from scipy.interpolate import interp1d

# %%
lowess = sm.nonparametric.lowess(y, x, frac=.3)
#gráfica
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Año')
plt.ylabel('Temperatura(C°)')
plt.title('Temperatura promedio anual')
plt.plot(x,y, color='black',label='Anual mean')




x=df[u'Year']
y=df[u'JD']
#
lowess_x = list(zip(*lowess))[0]
lowess_y = list(zip(*lowess))[1]


f = interp1d(lowess_x, lowess_y, bounds_error=False)

xnew = [i/10. for i in range(140)]


ynew = f(xnew)


plt.plot(x, y, '.',color='black')
plt.plot(lowess_x, lowess_y,color='red',label='Lowess')
plt.plot(xnew, ynew, )
plt.legend
plt.show()

# %%
# Lugar del ejemplo para realizar lowess function:
# http://stackoverflow.com/questions/36252434/predicting-on-new-data-using-locally-weighted-regression-loess-lowess

# %%
df.boxplot(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-da41a636a2cc> in <module>()
# ----> 1 df.boxplot(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
#
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5579     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5580                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# ...

# %%
df.Jan= pd.to_numeric(df.Jan, errors='coerce')
df.Feb= pd.to_numeric(df.Feb, errors='coerce')
df.Mar= pd.to_numeric(df.Mar, errors='coerce')
df.Apr= pd.to_numeric(df.Apr, errors='coerce')
df.May= pd.to_numeric(df.May, errors='coerce')
df.Jun= pd.to_numeric(df.Jun, errors='coerce')
df.Jul= pd.to_numeric(df.Jul, errors='coerce')
df.Aug= pd.to_numeric(df.Aug, errors='coerce')
df.Sep= pd.to_numeric(df.Sep, errors='coerce')
df.Oct= pd.to_numeric(df.Oct, errors='coerce')
df.Nov= pd.to_numeric(df.Nov, errors='coerce')
df.Dec= pd.to_numeric(df.Dec, errors='coerce')

# %%
df.boxplot(column=[u'Jan',u'Feb',u'Mar',u'Apr',u'May',u'Jun',u'Jul',u'Aug',u'Sep',u'Oct',u'Nov',u'Dec'])
mplt.ylabel('Temperatura (C°)')
mplt.title('Temperatura de los meses, Año 1880-2017')
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':

# %%
mplt.show()
